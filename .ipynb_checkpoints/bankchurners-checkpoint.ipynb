# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
# %pip install h5py graphviz pydot

data = pd.read_csv('BankChurners.csv')
pd.set_option('display.max_columns', None)
# Out:
# Requirement already satisfied: h5py in c:\users\ibigb\appdata\local\programs\python\python311\lib\site-packages (3.12.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: graphviz in c:\users\ibigb\appdata\local\programs\python\python311\lib\site-packages (0.20.3)
# Requirement already satisfied: pydot in c:\users\ibigb\appdata\local\programs\python\python311\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\ibigb\appdata\local\programs\python\python311\lib\site-packages (from h5py) (1.26.4)
# Requirement already satisfied: pyparsing>=3.0.9 in c:\users\ibigb\appdata\local\programs\python\python311\lib\site-packages (from pydot) (3.1.4)

# %%
data.dropna(inplace = True)
print(f'dataframe rows: {data.shape[0]} \ndataframe columns: {data.shape[1]} \n')
cats = data.select_dtypes(include = ['object', 'category'])
nums = data.select_dtypes(include = 'number')

display(cats.head(4))
display(nums.head(2))
# Out:
# dataframe rows: 10127
# dataframe columns: 21
#       Attrition_Flag Gender Education_Level Marital_Status Income_Category  \
# 0  Existing Customer      M     High School        Married     $60K - $80K
# 1  Existing Customer      F        Graduate         Single  Less than $40K
# 2  Existing Customer      M        Graduate        Married    $80K - $120K
# 3  Existing Customer      F     High School        Unknown  Less than $40K
#
#   Card_Category
# 0          Blue
# 1          Blue
# 2          Blue
# 3          Blue
#    CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# 0  768805383            45                3              39
# 1  818770008            49                5              44
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105

# %%
frame = data.copy()

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for i in cats:
  frame[i] = encoder.fit_transform(frame[i])

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
for i in nums:
  frame[[i]] = scaler.fit_transform(frame[[i]])

print(f'Transformed Dataset')
display(frame.head())

y = frame.Attrition_Flag
x = frame.drop(['Attrition_Flag'], axis = 1)
# Out:
# Transformed Dataset
#    CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0   0.802878               1     -0.165406       1         0.503368
# 1   2.156861               1      0.333570       0         2.043199
# 2  -0.682769               1      0.583058       1         0.503368
# 3   0.832862               1     -0.789126       0         1.273283
# 4  -0.814896               1     -0.789126       1         0.503368
#
#    Education_Level  Marital_Status  Income_Category  Card_Category  \
# 0                3               1                2              0
# 1                2               2                4              0
# 2                2               1                3              0
# 3                3               3                4              0
# 4                5               1                2              0
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0        0.384621                  0.763943               -1.327136
# 1        1.010715                  1.407306               -1.327136
# 2        0.008965                  0.120579               -1.327136
# 3       -0.241473                 -0.522785                1.641478
# 4       -1.869317                  0.763943               -1.327136
#
#    Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0               0.492404      0.446622            -0.473422         0.488971
# 1              -0.411616     -0.041367            -0.366667        -0.008486
# 2              -2.219655     -0.573698            -1.426858        -0.445658
# 3              -1.315636     -0.585251             1.661686        -0.734100
# 4              -2.219655     -0.430877            -1.426858        -0.302868
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0              2.623494        -0.959707       -0.973895             3.834003
# 1              3.563293        -0.916433       -1.357340            12.608573
# 2              8.367214        -0.740982       -1.911206             6.807864
# 3              2.942843        -0.951758       -1.911206             6.807864
# 4              6.455682        -1.056263       -1.570365             7.509325
#
#    Avg_Utilization_Ratio
# 0              -0.775882
# 1              -0.616276
# 2              -0.997155
# 3               1.759686
# 4              -0.997155

# %%
import xgboost as xgb
model = xgb.XGBClassifier()
model.fit(x,y)

xgb.plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
sel = ['CLIENTNUM', 'Customer_Age', 'Dependent_count',
       'Total_Relationship_Count', 'Months_Inactive_12_mon', 'Months_on_book',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']

new_frame = x[sel]
new_frame.head()
# Out:
#    CLIENTNUM  Customer_Age  Dependent_count  Total_Relationship_Count  \
# 0   0.802878     -0.165406         0.503368                  0.763943
# 1   2.156861      0.333570         2.043199                  1.407306
# 2  -0.682769      0.583058         0.503368                  0.120579
# 3   0.832862     -0.789126         1.273283                 -0.522785
# 4  -0.814896     -0.789126         0.503368                  0.763943
#
#    Months_Inactive_12_mon  Months_on_book  Contacts_Count_12_mon  \
# 0               -1.327136        0.384621               0.492404
# 1               -1.327136        1.010715              -0.411616
# 2               -1.327136        0.008965              -2.219655
# 3                1.641478       -0.241473              -1.315636
# 4               -1.327136       -1.869317              -2.219655
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0      0.446622            -0.473422         0.488971              2.623494
# 1     -0.041367            -0.366667        -0.008486              3.563293
# 2     -0.573698            -1.426858        -0.445658              8.367214
# 3     -0.585251             1.661686        -0.734100              2.942843
# 4     -0.430877            -1.426858        -0.302868              6.455682
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0        -0.959707       -0.973895             3.834003              -0.775882
# 1        -0.916433       -1.357340            12.608573              -0.616276
# 2        -0.740982       -1.911206             6.807864              -0.997155
# 3        -0.951758       -1.911206             6.807864               1.759686
# 4        -1.056263       -1.570365             7.509325              -0.997155

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

x_train, x_test, y_train, y_test = train_test_split(new_frame, y, test_size = 0.08, random_state = 100000, stratify = y)
print(f'x_train: {x_train.shape}')
print(f'x_test: {x_test.shape}')
print('y_train: {}'.format(y_train.shape))
print('y_test: {}'.format(y_test.shape))
# Out:
# x_train: (9316, 15)
# x_test: (811, 15)
# y_train: (9316,)
# y_test: (811,)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units = 15, activation = 'relu'),
    tf.keras.layers.Dense(40, activation = 'relu'),
    tf.keras.layers.Dense(35, activation = 'relu'),
    tf.keras.layers.Dense(20, activation = 'relu'),
    tf.keras.layers.Dense(10, activation = 'relu'),
    
    tf.keras.layers.Dense(1, activation = 'sigmoid'),
])

model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

model.fit(x_train, y_train, epochs = 30 )
# Out:
# Epoch 1/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7196 - loss: 0.5343
# Epoch 2/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8551 - loss: 0.3006
# Epoch 3/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9088 - loss: 0.2327
# Epoch 4/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9170 - loss: 0.2101
# Epoch 5/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9240 - loss: 0.1947
# Epoch 6/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9302 - loss: 0.1773
# Epoch 7/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9336 - loss: 0.1692
# Epoch 8/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9341 - loss: 0.1697
# Epoch 9/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9416 - loss: 0.1539
# Epoch 10/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9367 - loss: 0.1588
# Epoch 11/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9387 - loss: 0.1527
# Epoch 12/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9427 - loss: 0.1484
# Epoch 13/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9458 - loss: 0.1426
# Epoch 14/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9437 - loss: 0.1353
# Epoch 15/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9464 - loss: 0.1372
# Epoch 16/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9486 - loss: 0.1315
# Epoch 17/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9442 - loss: 0.1380
# Epoch 18/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9471 - loss: 0.1355
# Epoch 19/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9478 - loss: 0.1373
# Epoch 20/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9497 - loss: 0.1249
# Epoch 21/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9535 - loss: 0.1208
# Epoch 22/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9456 - loss: 0.1296
# Epoch 23/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9523 - loss: 0.1294
# Epoch 24/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9473 - loss: 0.1312
# Epoch 25/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9514 - loss: 0.1221
# Epoch 26/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9521 - loss: 0.1160
# Epoch 27/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9565 - loss: 0.1129
# Epoch 28/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9548 - loss: 0.1163
# Epoch 29/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9535 - loss: 0.1212
# Epoch 30/30
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9556 - loss: 0.1176

# %%
score = model.evaluate(x_test, y_test, verbose = 0)
print(f'Test Loss: {score[0]}\Test Accuracy: {score[1]}')
# Out:
# Test Loss: 0.19093617796897888\Test Accuracy: 0.9346485733985901

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5).astype(int)  #............................................... set a 50% confidence level that the customer doesnt stop buying
outcome = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred.flatten()})
outcome
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#       Actual  Predicted
# 2691       1          1
# 3857       1          1
# 3289       0          1
# 8625       1          1
# 2238       1          1
# ...      ...        ...
# 5439       1          1
# 8955       1          1
# 1892       1          1
# 6478       0          1
# 134        1          1
#
# [811 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import classification_report

revealer = confusion_matrix(y_pred, y_test)
sns.set(style = 'darkgrid')
sns.heatmap(revealer/np.sum(revealer), annot=True, cmap='crest', fmt='.1%', linewidth=1)

print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.79       119
#            1       0.97      0.95      0.96       692
#
#     accuracy                           0.93       811
#    macro avg       0.86      0.89      0.87       811
# weighted avg       0.94      0.93      0.94       811

# %%
model.save('BankChurners.keras')
